# %%
# Import the necessary modules and libraries
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# Create a random dataset, basicamente se crea una funcion dependiente, X y Y(X)
rng = np.random.RandomState(3)
X = np.sort(3 * rng.rand(80, 1), axis=0) ## sort para ordenar, rand(80,1) crea una matriz de 80x1
y = np.cos(X).ravel() ## .ravel para volver una matriz en un vector
y[::5] += 3 * (0.5 - rng.rand(16)) ## esta linea es para agregar puntos random fuera de lo comun!

# Fit regression model, o aca es donde se entrena el modelo, max_depth es que tan rigido se vuelve el modelo
regr_1 = DecisionTreeRegressor(max_depth=1) 
regr_2 = DecisionTreeRegressor(max_depth=8)
regr_1.fit(X, y)
regr_2.fit(X, y)

# Aca se establecen los puntos X que se quieren predecir !
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# Plot the results
plt.figure()
plt.scatter(X, y, s=20, edgecolor="black", c="darkorange", label="data")
plt.plot(X_test, y_1, color="cornflowerblue", label="max_depth=1", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=7", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()
